# %%
#imprting libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
plt.style.use('ggplot')
# %matplotlib inline

# %%
# !ls
# Out:
# 3.csv  data  img  README.md  Untitled1.ipynb  Untitled.ipynb

# %%
#importing csv file by Pandas
df = pd.read_csv('3.csv')

# %%
#original shape of the dataframe
df.shape
# Out:
# (14900, 64)

# %%
#list of original dataframe features
df.columns
# Out:
# Index(['SUBJID', 'SAMPID', 'SMATSSCR', 'SMCENTER', 'SMPTHNTS', 'SMRIN', 'SMTS',
#        'SMTSD', 'SMUBRID', 'SMTSISCH', 'SMTSPAX', 'SMNABTCH', 'SMNABTCHT',
#        'SMNABTCHD', 'SMGEBTCH', 'SMGEBTCHD', 'SMGEBTCHT', 'SMAFRZE', 'SMGTC',
#        'SME2MPRT', 'SMCHMPRS', 'SMNTRART', 'SMNUMGPS', 'SMMAPRT', 'SMEXNCRT',
#        'SM550NRM', 'SMGNSDTC', 'SMUNMPRT', 'SM350NRM', 'SMRDLGTH', 'SMMNCPB',
#        'SME1MMRT', 'SMSFLGTH', 'SMESTLBS', 'SMMPPD', 'SMNTERRT', 'SMRRNANM',
#        'SMRDTTL', 'SMVQCFL', 'SMMNCV', 'SMTRSCPT', 'SMMPPDPR', 'SMCGLGTH',
#        'SMGAPPCT', 'SMUNPDRD', 'SMNTRNRT', 'SMMPUNRT', 'SMEXPEFF', 'SMMPPDUN',
#        'SME2MMRT', 'SME2ANTI', 'SMALTALG', 'SME2SNSE', 'SMMFLGTH', 'SME1ANTI',
#        'SMSPLTRD', 'SMBSMMRT', 'SME1SNSE', 'SME1PCTS', 'SMRRNART', 'SME1MPRT',
#        'SMNUM5CD', 'SMDPMPRT', 'SME2PCTS'],
#       dtype='object')

# %%
#finding unique values of all features and getting a sense of how many of them are there!
for feature in df.columns:
    print(feature, len(df[feature].unique()))
# Out:
# SUBJID 752
# SAMPID 14900
# SMATSSCR 5
# SMCENTER 9
# SMPTHNTS 7969
# SMRIN 56
# SMTS 31
# SMTSD 51
# SMUBRID 50
# SMTSISCH 1654
# SMTSPAX 1183
# SMNABTCH 1418
# SMNABTCHT 13
# SMNABTCHD 712
# SMGEBTCH 270
# SMGEBTCHD 201
# SMGEBTCHT 11
# SMAFRZE 5
# SMGTC 380
# SME2MPRT 11850
# SMCHMPRS 23
# SMNTRART 11984
# SMNUMGPS 1
# SMMAPRT 11752
# SMEXNCRT 12074
# SM550NRM 1
# SMGNSDTC 5691
# SMUNMPRT 2
# SM350NRM 1
# SMRDLGTH 3
# SMMNCPB 1
# SME1MMRT 12097
# SMSFLGTH 333
# SMESTLBS 2
# SMMPPD 12100
# SMNTERRT 12097
# SMRRNANM 12045
# SMRDTTL 12100
# SMVQCFL 12088
# SMMNCV 1
# SMTRSCPT 5747
# SMMPPDPR 12102
# SMCGLGTH 1
# SMGAPPCT 1
# SMUNPDRD 2
# SMNTRNRT 12097
# SMMPUNRT 11752
# SMEXPEFF 12091
# SMMPPDUN 12100
# SME2MMRT 12097
# SME2ANTI 12096
# SMALTALG 12098
# SME2SNSE 12098
# SMMFLGTH 388
# SME1ANTI 12097
# SMSPLTRD 12099
# SMBSMMRT 12098
# SME1SNSE 12097
# SME1PCTS 11725
# SMRRNART 12097
# SME1MPRT 11622
# SMNUM5CD 1
# SMDPMPRT 2
# SME2PCTS 11604

# %%
#SUBJID --> Subject ID, GTEx Public Donor ID
# (df['SUBJID'].unique())
# len(df['SUBJID'].unique())
# df.groupby('SUBJID').mean()

# %%
# SMATSSCR --> Autolysis Score, assigned by a pathologist during a visual inspection of the histology image. 0 to 3 (None, Mild, Moderate, and Severe)
(df['SMATSSCR'].unique())
# len(df['SMATSSCR'].unique())
# df.groupby('SMATSSCR').count()
# df.groupby('SMATSSCR').mean()
# 2443+6858+1035+118 = 10454
#number of sample w/o Autolysis score 14900-10454
# Out:
# array([nan,  1.,  0.,  2.,  3.])

# %%
fig, ax = plt.subplots()
ax.bar(df.groupby('SMATSSCR').mean().index, df.groupby('SMATSSCR').mean()['SMTSISCH'])
ax.set_ylim(400,900)
ax.set_xlim(-1,4)
ax.set_xlabel('Autolysis Score, assigned by a pathologist\nduring a visual inspection of the histology\n image. 0 to 3 (None, Mild, Moderate, and Severe)')
ax.set_ylabel('Total Ischemic time for a sample')
# Out:
# Text(0, 0.5, 'Total Ischemic time for a sample')

# %%
fig, ax = plt.subplots()
ax.bar(df.groupby('SMATSSCR').mean().index, df.groupby('SMATSSCR').mean()['SMRIN'])
ax.set_ylim(6,7.5)
ax.set_xlim(-1,4)
ax.set_xlabel('Autolysis Score, assigned by a pathologist\nduring a visual inspection of the histology\n image. 0 to 3 (None, Mild, Moderate, and Severe)')
ax.set_ylabel('RIN Number: RNA Integrity Number,\n as measured by Agilent Bioanalyzer')
# Out:
# Text(0, 0.5, 'RIN Number: RNA Integrity Number,\n as measured by Agilent Bioanalyzer')

# %%
# SMCENTER --> Code for BSS collection site (NOT THAT IMPORTANT SO FAR!)
# (df['SMCENTER'].unique())
# len(df['SMCENTER'].unique())

# %%
df.describe()
# Out:
#           SMATSSCR         SMRIN      SMTSISCH       SMTSPAX      SME2MPRT  \
# count  10454.00000  12987.000000  13293.000000  10449.000000  12102.000000
# mean       0.88789      7.381890    482.777627    865.873864      0.962858
# std        0.60441      1.056181    411.654668    308.106123      0.093646
# min        0.00000      3.100000  -1226.000000    240.000000      0.092491
# 25%        1.00000      6.600000    173.000000    603.000000      0.981405
# 50%        1.00000      7.300000    389.000000    863.000000      0.985490
# 75%        1.00000      8.000000    772.000000   1099.000000      0.988005
# max        3.00000     10.000000   2029.000000   1673.000000      0.997623
#
#            SMCHMPRS      SMNTRART  SMNUMGPS       SMMAPRT      SMEXNCRT  ...  \
# count  12102.000000  12102.000000       0.0  12102.000000  12102.000000  ...
# mean       0.133614      0.962523       NaN      0.966706      0.797197  ...
# ...

# %%
# SMRIN --> RIN Number: RNA Integrity Number, as measured by Agilent Bioanalyzer
# (df['SMRIN'].unique())
len(df['SMRIN'].unique())
# Out:
# 56

# %%
df.columns
# Out:
# Index(['SUBJID', 'SAMPID', 'SMATSSCR', 'SMCENTER', 'SMPTHNTS', 'SMRIN', 'SMTS',
#        'SMTSD', 'SMUBRID', 'SMTSISCH', 'SMTSPAX', 'SMNABTCH', 'SMNABTCHT',
#        'SMNABTCHD', 'SMGEBTCH', 'SMGEBTCHD', 'SMGEBTCHT', 'SMAFRZE', 'SMGTC',
#        'SME2MPRT', 'SMCHMPRS', 'SMNTRART', 'SMNUMGPS', 'SMMAPRT', 'SMEXNCRT',
#        'SM550NRM', 'SMGNSDTC', 'SMUNMPRT', 'SM350NRM', 'SMRDLGTH', 'SMMNCPB',
#        'SME1MMRT', 'SMSFLGTH', 'SMESTLBS', 'SMMPPD', 'SMNTERRT', 'SMRRNANM',
#        'SMRDTTL', 'SMVQCFL', 'SMMNCV', 'SMTRSCPT', 'SMMPPDPR', 'SMCGLGTH',
#        'SMGAPPCT', 'SMUNPDRD', 'SMNTRNRT', 'SMMPUNRT', 'SMEXPEFF', 'SMMPPDUN',
#        'SME2MMRT', 'SME2ANTI', 'SMALTALG', 'SME2SNSE', 'SMMFLGTH', 'SME1ANTI',
#        'SMSPLTRD', 'SMBSMMRT', 'SME1SNSE', 'SME1PCTS', 'SMRRNART', 'SME1MPRT',
#        'SMNUM5CD', 'SMDPMPRT', 'SME2PCTS'],
#       dtype='object')

# %%
new_df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-2bece3502c85> in <module>
# ----> 1 new_df.columns
#
# NameError: name 'new_df' is not defined

# %%
plt.scatter(df['SMTSPAX'], df['SMEXPEFF'], c = df['SMEXPEFF'], cmap = 'Accent')
plt.xlabel('Time a sample spent in the PAXgene fixative')
plt.ylabel('Expression Profiling Efficiency:\n Ratio of exon reads to total reads')
# Out:
# Text(0, 0.5, 'Expression Profiling Efficiency:\n Ratio of exon reads to total reads')

# %%
plt.scatter(df['SMTSISCH'], df['SMEXPEFF'], c = df['SMEXPEFF'], cmap = 'Accent')
plt.xlabel('Total Ischemic time for a sample')
plt.ylabel('Expression Profiling Efficiency:\n Ratio of exon reads to total reads')
# Out:
# Text(0, 0.5, 'Expression Profiling Efficiency:\n Ratio of exon reads to total reads')

# %%
plt.scatter(df['SMRIN'], df['SMATSSCR'], c = df['SMRIN'], cmap = 'Accent')
plt.xlabel('Total Ischemic time for a sample')
plt.ylabel('Autolysis Score, assigned by a pathologist\nduring a visual inspection of the histology\n 0 to 3 (None, Mild, Moderate, and Severe)')
# Out:
# Text(0, 0.5, 'Autolysis Score, assigned by a pathologist\nduring a visual inspection of the histology\n 0 to 3 (None, Mild, Moderate, and Severe)')

# %%
#SMTS --> Tissue Type, area from which the tissue sample was taken.
(df['SMTS'].unique())
len(df['SMTS'].unique())
# Out:
# 31

# %%
SMTS_SMNABTCHT_df = df.groupby(['SMTS','SMNABTCHT']).count().sort_values('SUBJID', ascending = False)
SMTS_df.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-58cac52f33a2> in <module>
#       1 SMTS_SMNABTCHT_df = df.groupby(['SMTS','SMNABTCHT']).count().sort_values('SUBJID', ascending = False)
# ----> 2 SMTS_df.head(20)
#
# NameError: name 'SMTS_df' is not defined

# %%
SMTS_df = df.groupby('SMTS').count().sort_values('SUBJID', ascending = False).head(10)
SMTS_df.head(10)
fig, ax = plt.subplots(figsize= (20,4))
ax = plt.bar(SMTS_df.index, height = SMTS_df['SUBJID'])
fig.suptitle('Sample Origin Tissue', fontsize=20)
plt.rc('xtick', labelsize=15) 
plt.rc('ytick', labelsize=20)

# %%
#SMTSD --> Tissue Type, more specific detail of tissue type
# (df['SMTSD'].unique())
len(df['SMTSD'].unique())

# %%
#SMUBRID --> Uberon ID, anatomical location as described by the Uber Anatomy Ontology (UBERON)
# (df['SMUBRID'].unique())
len(df['SMUBRID'].unique())

# %%
# SMTSISCH --> Total Ischemic time for a sample
# (df['SMTSISCH'].unique())
len(df['SMTSISCH'].unique())

# %%
# SMTSPAX --> Time a sample spent in the PAXgene fixative
# (df['SMTSPAX'].unique())
len(df['SMTSPAX'].unique())

# %%
#SMNABTCH --> Nucleic Acid Isolation Batch ID
# (df['SMNABTCH'].unique())
len(df['SMNABTCH'].unique())

# %%
#SMNABTCHT --> Type of nucleic acid isolation batch
# (df['SMNABTCHT'].unique())
len(df['SMNABTCHT'].unique())

# %%
SMNABTCHT_df = df.groupby('SMNABTCHT').count().sort_values('SUBJID', ascending = False).head(5)
SMNABTCHT_df.head(5)
fig, ax = plt.subplots(figsize= (10,4))
ax.bar(SMNABTCHT_df.index, height = SMNABTCHT_df['SUBJID'])
fig.suptitle('Type of nucleic acid isolation batch', fontsize=15 )
plt.rc('xtick', labelsize=40)
plt.rc('ytick', labelsize=20)
ax.set_xticklabels(SMNABTCHT_df.index,rotation=45, fontsize=8, ha = 'right')
# Out:
# [Text(0, 0, 'RNA Extraction from Paxgene-derived Lysate Plate Based'),
#  Text(0, 0, 'RNA isolation_PAXgene Tissue miRNA'),
#  Text(0, 0, 'DNA or RNA Extraction from Paxgene-derived Lysate Plate Based'),
#  Text(0, 0, 'RNA isolation_Trizol Manual (Cell Pellet)'),
#  Text(0, 0, 'DNA isolation_Whole Blood_QIAGEN Puregene (Manual)')]

# %%
# create data
x = np.random.rand(13)
y = np.random.rand(13)
z = SMNABTCHT_df['SUBJID']
 
fig, ax = plt.subplots(figsize= (10,4))
ax = plt.scatter(x, y, s=z/2, alpha=0.5)
fig.suptitle('SMNABTCHT', fontsize=5)

plt.rc('xtick', labelsize=1) 
plt.rc('ytick', labelsize=1)

# %%
fig, ax = plt.subplots(figsize= (6,6))
ax = plt.scatter(new_df['SMNTRNRT'], new_df['SMEXNCRT'])
fig.suptitle('SMNTRNRT vs. SMEXNCRT', fontsize=20)

plt.xlabel('Intronic Rate: The fraction of reads that map within introns')
plt.ylabel('Exonic Rate: Fraction of reads that map within exons')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-ac8193b00cb2> in <module>
#       1 fig, ax = plt.subplots(figsize= (6,6))
# ----> 2 ax = plt.scatter(new_df['SMNTRNRT'], new_df['SMEXNCRT'])
#       3 fig.suptitle('SMNTRNRT vs. SMEXNCRT', fontsize=20)
#       4
#       5 plt.xlabel('Intronic Rate: The fraction of reads that map within introns')
#
# NameError: name 'new_df' is not defined

# %%
#SMNABTCHD --> Date of nucleic acid isolation batch
# (df['SMNABTCHD'].unique())
len(df['SMNABTCHD'].unique())

# %%
#SMGEBTCH --> Genotype or Expression Batch ID
# (df['SMGEBTCH'].unique())
len(df['SMGEBTCH'].unique())

# %%
#SMGEBTCHD --> Date of genotype or expression batch
# (df['SMGEBTCHD'].unique())
len(df['SMGEBTCHD'].unique())

# %%
#SMGEBTCHT --> Type of genotype or expression batch
(df['SMGEBTCHT'].unique())
len(df['SMGEBTCHT'].unique())

# %%
#SMAFRZE --> Samples included in the GTEx Analysis Freeze
(df['SMAFRZE'].unique())
# len(df['SMAFRZE'].unique())

# %%
# SMGTC --> Name of the genotype gtc file
# (df['SMGTC'].unique())
# len(df['SMGTC'].unique())

# %%
# SME2MPRT --> End 2 Mapping Rate: Number of End 2 mapped reads divided by the total number of End 1 reads
# (df['SME2MPRT'].unique())
len(df['SME2MPRT'].unique())
# Out:
# 11850

# %%
#SMCHMPRS --> Chimeric Pairs: Number of reads whose mates map to different genes
(df['SMCHMPRS'].unique())
len(df['SMCHMPRS'].unique())
# Out:
# 23

# %%
SMTS_SMCHMPRS_df = new_df.groupby(['SMTS', 'SMTSD']).mean()
SMTS_SMCHMPRS_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-875ab740186d> in <module>
# ----> 1 SMTS_SMCHMPRS_df = new_df.groupby(['SMTS', 'SMTSD']).mean()
#       2 SMTS_SMCHMPRS_df
#
# NameError: name 'new_df' is not defined

# %%
# SMNTRART --> Intragenic Rate: The fraction of reads that map within genes (within introns or exons)
(df['SMNTRART'].unique())
len(df['SMNTRART'].unique())
# Out:
# 11984

# %%
df.plot.scatter('SMTSPAX', 'SMRIN')
# new_df.columns

# %%
plt.hist(df['SMRIN'], bins=25);

# %%
df.columns
# Out:
# Index(['SUBJID', 'SAMPID', 'SMATSSCR', 'SMCENTER', 'SMPTHNTS', 'SMRIN', 'SMTS',
#        'SMTSD', 'SMUBRID', 'SMTSISCH', 'SMTSPAX', 'SMNABTCH', 'SMNABTCHT',
#        'SMNABTCHD', 'SMGEBTCH', 'SMGEBTCHD', 'SMGEBTCHT', 'SMAFRZE', 'SMGTC',
#        'SME2MPRT', 'SMCHMPRS', 'SMNTRART', 'SMNUMGPS', 'SMMAPRT', 'SMEXNCRT',
#        'SM550NRM', 'SMGNSDTC', 'SMUNMPRT', 'SM350NRM', 'SMRDLGTH', 'SMMNCPB',
#        'SME1MMRT', 'SMSFLGTH', 'SMESTLBS', 'SMMPPD', 'SMNTERRT', 'SMRRNANM',
#        'SMRDTTL', 'SMVQCFL', 'SMMNCV', 'SMTRSCPT', 'SMMPPDPR', 'SMCGLGTH',
#        'SMGAPPCT', 'SMUNPDRD', 'SMNTRNRT', 'SMMPUNRT', 'SMEXPEFF', 'SMMPPDUN',
#        'SME2MMRT', 'SME2ANTI', 'SMALTALG', 'SME2SNSE', 'SMMFLGTH', 'SME1ANTI',
#        'SMSPLTRD', 'SMBSMMRT', 'SME1SNSE', 'SME1PCTS', 'SMRRNART', 'SME1MPRT',
#        'SMNUM5CD', 'SMDPMPRT', 'SME2PCTS'],
#       dtype='object')

# %%
plt.hist(df['SMATSSCR'], bins=8);

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.hist(df['SMTS'], bins=25, stacked = False )
ax.set_title('SMST')
ax.set_xlabel('x');

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.hist(df['SMTSD'], bins=25, stacked = False )
ax.set_title('SMSTSD');

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.hist(df['SMUBRID'], bins=25, stacked = False );

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.hist(df['SMTSISCH'], bins=25, stacked = False )
ax.set_title('SMTSISCH');

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.hist(df['SMTSPAX'], bins=25, stacked = False )
ax.set_title('SMTSPAX');

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.hist(df['SME2MPRT'], bins=25, stacked = False )
ax.set_title('SME2MPRT');

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.hist(df['SMCHMPRS'], bins = 50, stacked = False )
ax.set_title('SMCHMPRS');

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.hist(df['SMNABTCHT'], bins = 50, stacked = False )
ax.set_title('SMNABTCHT');

# %%
fig, ax = plt.subplots(figsize = (10,4))
ax.scatter(df['SMCHMPRS'], df['SME2MPRT'], )
ax.set_title('scatter');

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [SUBJID, SAMPID, SMATSSCR, SMCENTER, SMPTHNTS, SMRIN, SMTS, SMTSD, SMUBRID, SMTSISCH, SMTSPAX, SMNABTCH, SMNABTCHT, SMNABTCHD, SMGEBTCH, SMGEBTCHD, SMGEBTCHT, SMAFRZE, SMGTC, SME2MPRT, SMCHMPRS, SMNTRART, SMNUMGPS, SMMAPRT, SMEXNCRT, SM550NRM, SMGNSDTC, SMUNMPRT, SM350NRM, SMRDLGTH, SMMNCPB, SME1MMRT, SMSFLGTH, SMESTLBS, SMMPPD, SMNTERRT, SMRRNANM, SMRDTTL, SMVQCFL, SMMNCV, SMTRSCPT, SMMPPDPR, SMCGLGTH, SMGAPPCT, SMUNPDRD, SMNTRNRT, SMMPUNRT, SMEXPEFF, SMMPPDUN, SME2MMRT, SME2ANTI, SMALTALG, SME2SNSE, SMMFLGTH, SME1ANTI, SMSPLTRD, SMBSMMRT, SME1SNSE, SME1PCTS, SMRRNART, SME1MPRT, SMNUM5CD, SMDPMPRT, SME2PCTS]
# Index: []
#
# [0 rows x 64 columns]

# %%
df.head()
# Out:
#   SUBJID          SAMPID  SMATSSCR SMCENTER SMPTHNTS  SMRIN         SMTS  \
# 0  K-562  K-562-SM-26GMQ       NaN      NaN      NaN    9.5  Bone Marrow
# 1  K-562  K-562-SM-2YUNN       NaN      NaN      NaN    9.5  Bone Marrow
# 2  K-562  K-562-SM-2S1OR       NaN      NaN      NaN    9.5  Bone Marrow
# 3  K-562  K-562-SM-2S1Q5       NaN      NaN      NaN    9.5  Bone Marrow
# 4  K-562  K-562-SM-2S1RI       NaN      NaN      NaN    9.5  Bone Marrow
#
#                               SMTSD      SMUBRID  SMTSISCH  ...    SME1ANTI  \
# 0  Cells - Leukemia cell line (CML)  EFO_0002067       NaN  ...         NaN
# 1  Cells - Leukemia cell line (CML)  EFO_0002067       NaN  ...  17874979.0
# 2  Cells - Leukemia cell line (CML)  EFO_0002067       NaN  ...   2759194.0
# 3  Cells - Leukemia cell line (CML)  EFO_0002067       NaN  ...   4349266.0
# 4  Cells - Leukemia cell line (CML)  EFO_0002067       NaN  ...   8605564.0
#
# ...

# %%
df.iloc[1:, 19]
# Out:
# 1        0.814262
# 2        0.216187
# 3        0.349012
# 4        0.641674
# 5        0.403569
#            ...
# 14895    0.989030
# 14896    0.987606
# 14897    0.988732
# 14898    0.988633
# 14899    0.983459
# Name: SME2MPRT, Length: 14899, dtype: float64

# %%
df1 = df.iloc[:147,:]

# %%
df2 = df.iloc[160:7294,:]

# %%
df3 = df.iloc[8828:12365,:]

# %%
df4 = df.iloc[13375:13477,:]

# %%
df5 = df.iloc[13570:14674,:]

# %%
df6 = df.iloc[14768:14838,:]

# %%
df7 = df.iloc[14892:,:]

# %%
new_df = pd.concat([df1,df2,df3,df4,df5,df6,df7], axis = 0)

# %%
new_df.reset_index(inplace = True)

# %%
new_df.drop(columns = 'index', inplace = True)

# %%
new_df.drop(index = 0, inplace =True)

# %%
new_df.head()
# Out:
#   SUBJID          SAMPID  SMATSSCR SMCENTER SMPTHNTS  SMRIN         SMTS  \
# 1  K-562  K-562-SM-2YUNN       NaN      NaN      NaN    9.5  Bone Marrow
# 2  K-562  K-562-SM-2S1OR       NaN      NaN      NaN    9.5  Bone Marrow
# 3  K-562  K-562-SM-2S1Q5       NaN      NaN      NaN    9.5  Bone Marrow
# 4  K-562  K-562-SM-2S1RI       NaN      NaN      NaN    9.5  Bone Marrow
# 5  K-562  K-562-SM-2TC5E       NaN      NaN      NaN    9.5  Bone Marrow
#
#                               SMTSD      SMUBRID  SMTSISCH  ...    SME1ANTI  \
# 1  Cells - Leukemia cell line (CML)  EFO_0002067       NaN  ...  17874979.0
# 2  Cells - Leukemia cell line (CML)  EFO_0002067       NaN  ...   2759194.0
# 3  Cells - Leukemia cell line (CML)  EFO_0002067       NaN  ...   4349266.0
# 4  Cells - Leukemia cell line (CML)  EFO_0002067       NaN  ...   8605564.0
# 5  Cells - Leukemia cell line (CML)  EFO_0002067       NaN  ...   4906820.0
#
# ...

# %%
new_df.shape
# Out:
# (12101, 64)

# %%
new_df.drop(columns = 'SMPTHNTS', inplace = True)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12101 entries, 1 to 12101
# Data columns (total 63 columns):
# SUBJID       12101 non-null object
# SAMPID       12101 non-null object
# SMATSSCR     9781 non-null float64
# SMCENTER     11955 non-null object
# SMRIN        12101 non-null float64
# SMTS         12101 non-null object
# SMTSD        12101 non-null object
# SMUBRID      12101 non-null object
# SMTSISCH     10701 non-null float64
# SMTSPAX      9776 non-null float64
# SMNABTCH     12101 non-null object
# SMNABTCHT    12101 non-null object
# SMNABTCHD    12101 non-null object
# SMGEBTCH     12101 non-null object
# SMGEBTCHD    12101 non-null object
# SMGEBTCHT    12101 non-null object
# SMAFRZE      12101 non-null object
# SMGTC        0 non-null object
# SME2MPRT     12101 non-null float64
# SMCHMPRS     12101 non-null float64
# SMNTRART     12101 non-null float64
# SMNUMGPS     0 non-null float64
# SMMAPRT      12101 non-null float64
# ...

# %%
new_df.drop(columns = ['SMNUM5CD', 'SMGAPPCT', 'SMCGLGTH', 'SMMNCV'], inplace = True)

# %%
new_df.drop(columns = ['SMCENTER','SMTSPAX','SMGTC','SMNUMGPS','SM550NRM','SM350NRM'], inplace = True)

# %%
new_df.drop(columns = 'SMMNCPB', inplace= True)

# %%
new_df.iloc[:,:10].head()
# Out:
#   SUBJID          SAMPID  SMATSSCR  SMRIN         SMTS  \
# 1  K-562  K-562-SM-2YUNN       NaN    9.5  Bone Marrow
# 2  K-562  K-562-SM-2S1OR       NaN    9.5  Bone Marrow
# 3  K-562  K-562-SM-2S1Q5       NaN    9.5  Bone Marrow
# 4  K-562  K-562-SM-2S1RI       NaN    9.5  Bone Marrow
# 5  K-562  K-562-SM-2TC5E       NaN    9.5  Bone Marrow
#
#                               SMTSD      SMUBRID  SMTSISCH  SMNABTCH  \
# 1  Cells - Leukemia cell line (CML)  EFO_0002067       NaN  BP-17177
# 2  Cells - Leukemia cell line (CML)  EFO_0002067       NaN  BP-17177
# 3  Cells - Leukemia cell line (CML)  EFO_0002067       NaN  BP-17177
# 4  Cells - Leukemia cell line (CML)  EFO_0002067       NaN  BP-17177
# 5  Cells - Leukemia cell line (CML)  EFO_0002067       NaN  BP-17177
#
#                                    SMNABTCHT
# 1  RNA isolation_Trizol Manual (Cell Pellet)
# 2  RNA isolation_Trizol Manual (Cell Pellet)
# 3  RNA isolation_Trizol Manual (Cell Pellet)
# ...

# %%
new_df.iloc[:,10:20].head()
# Out:
#     SMNABTCHD    SMGEBTCH   SMGEBTCHD  SMGEBTCHT  SMAFRZE  SME2MPRT  SMCHMPRS  \
# 1  06/17/2011  LCSET-1433  06/09/2012  TruSeq.v1  EXCLUDE  0.814262       0.0
# 2  06/17/2011  LCSET-1464  06/08/2012  TruSeq.v1  EXCLUDE  0.216187       0.0
# 3  06/17/2011  LCSET-1465  06/02/2012  TruSeq.v1  EXCLUDE  0.349012       0.0
# 4  06/17/2011  LCSET-1466  05/21/2012  TruSeq.v1  EXCLUDE  0.641674       0.0
# 5  06/17/2011  LCSET-1477  05/27/2012  TruSeq.v1  EXCLUDE  0.403569       0.0
#
#    SMNTRART   SMMAPRT  SMEXNCRT
# 1  0.940678  0.815496  0.806363
# 2  0.902348  0.217397  0.746746
# 3  0.929981  0.354189  0.779190
# 4  0.934702  0.645468  0.782844
# 5  0.935133  0.400125  0.788126

# %%
new_df.iloc[:,20:30].head()
# Out:
#    SMGNSDTC  SMUNMPRT  SMRDLGTH  SME1MMRT  SMSFLGTH  SMESTLBS      SMMPPD  \
# 1   20971.0       1.0      76.0  0.001930     151.0       0.0  81164938.0
# 2   16193.0       1.0      76.0  0.004431     113.0       0.0  12964712.0
# 3   17504.0       1.0      76.0  0.002535     117.0       0.0  19708027.0
# 4   19031.0       1.0      76.0  0.001960     106.0       0.0  39452634.0
# 5   18052.0       1.0      76.0  0.003001     108.0       0.0  22712942.0
#
#    SMNTERRT  SMRRNANM     SMRDTTL
# 1  0.058978  636708.0  99528288.0
# 2  0.097371   93009.0  59636070.0
# 3  0.069712  150271.0  55642650.0
# 4  0.065001  339781.0  61122494.0
# 5  0.064371  184018.0  56764628.0

# %%
new_df.iloc[:,30:40].head()
# Out:
#       SMVQCFL  SMTRSCPT    SMMPPDPR  SMUNPDRD  SMNTRNRT  SMMPUNRT  SMEXPEFF  \
# 1   8575612.0   20990.0  40280924.0       0.0  0.134315  0.815496  0.657586
# 2  21671790.0   16196.0   6369612.0       0.0  0.155602  0.217397  0.162340
# 3   5414382.0   17509.0   9625009.0       0.0  0.150791  0.354189  0.275981
# 4   5915682.0   19045.0  19470050.0       0.0  0.151858  0.645468  0.505301
# 5  13282752.0   18059.0  11066983.0       0.0  0.147007  0.400125  0.315349
#
#      SMMPPDUN  SME2MMRT    SME2ANTI
# 1  81164938.0  0.003369  17526238.0
# 2  12964712.0  0.009754   2658733.0
# 3  19708027.0  0.017435   4125218.0
# 4  39452634.0  0.008113   8460038.0
# 5  22712942.0  0.017563   4931006.0

# %%
new_df.iloc[:,40:50].head()
# Out:
#      SMALTALG    SME2SNSE  SMMFLGTH    SME1ANTI    SMSPLTRD  SMBSMMRT  \
# 1  10869324.0  17847838.0     160.0  17874979.0  19309709.0  0.002648
# 2   2512259.0   2732450.0     109.0   2759194.0   2683593.0  0.007078
# 3   2760142.0   4234606.0     116.0   4349266.0   4165579.0  0.009876
# 4   5110882.0   8516192.0     101.0   8605564.0   8704660.0  0.005018
# 5   3670759.0   5004214.0     107.0   4906820.0   5075859.0  0.010345
#
#      SME1SNSE   SME1PCTS  SMRRNART  SME1MPRT
# 1  17603256.0  49.617058  0.006397  0.816731
# 2   2693329.0  49.396010  0.001560  0.218608
# 3   4260286.0  49.483250  0.002701  0.359366
# 4   8571251.0  49.900116  0.005559  0.649263
# 5   4845142.0  49.683765  0.003242  0.396680

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12101 entries, 1 to 12101
# Data columns (total 52 columns):
# SUBJID       12101 non-null object
# SAMPID       12101 non-null object
# SMATSSCR     9781 non-null float64
# SMRIN        12101 non-null float64
# SMTS         12101 non-null object
# SMTSD        12101 non-null object
# SMUBRID      12101 non-null object
# SMTSISCH     10701 non-null float64
# SMNABTCH     12101 non-null object
# SMNABTCHT    12101 non-null object
# SMNABTCHD    12101 non-null object
# SMGEBTCH     12101 non-null object
# SMGEBTCHD    12101 non-null object
# SMGEBTCHT    12101 non-null object
# SMAFRZE      12101 non-null object
# SME2MPRT     12101 non-null float64
# SMCHMPRS     12101 non-null float64
# SMNTRART     12101 non-null float64
# SMMAPRT      12101 non-null float64
# SMEXNCRT     12101 non-null float64
# SMGNSDTC     12101 non-null float64
# SMUNMPRT     12101 non-null float64
# SMRDLGTH     12101 non-null float64
# ...

# %%
fig, ax = plt.subplots()
ax.scatter(new_df['SMMPUNRT'], new_df['SMEXPEFF'])

# %%
fig, ax = plt.subplots()
ax.scatter(new_df['SMBSMMRT'], new_df['SMRRNART'])

# %%
new_df.hist(figsize= (20,20), bins = 50)
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
# pd.plotting.scatter_matrix(new_df, figsize=(30,30))

# %%
pd.plotting.scatter_matrix(new_df.iloc[:,40:50], figsize=(30,30))
# Out:
# /home/farzady/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/misc.py:80: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# /home/farzady/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/misc.py:81: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# /home/farzady/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/misc.py:71: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[i])
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2317b3810>,
# ...
#       dtype=object)

# %%
# SMEXPEFF by batch type
# new_df.groupby('SMNABTCHT').mean()
new_df.groupby('SMNABTCHT').mean()['SMEXPEFF']
# new_df.groupby('SMNABTCHT').std()['SMEXPEFF']
# Out:
# SMNABTCHT
# DNA or RNA Extraction from Paxgene-derived Lysate Plate Based    0.785057
# RNA Extraction from Paxgene-derived Lysate Plate Based           0.787034
# RNA isolation_PAXgene Blood RNA (Manual)                         0.718480
# RNA isolation_PAXgene Tissue miRNA                               0.766025
# RNA isolation_QIAGEN miRNeasy                                    0.660413
# RNA isolation_Trizol Manual (Cell Pellet)                        0.719450
# Name: SMEXPEFF, dtype: float64

# %%
fig, ax = plt.subplots()
ax.bar(new_df.groupby('SMNABTCHT').mean()['SMEXPEFF'].index, new_df.groupby('SMNABTCHT').mean()['SMEXPEFF'])
# Out:
# <BarContainer object of 6 artists>

# %%
pd.plotting.scatter_matrix(new_df.iloc[:,35:40], figsize=(30,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb233b05fd0>,
# ...
#       dtype=object)

# %%
fig, ax = plt.subplots()
ax.scatter(new_df['SMMPUNRT'], new_df['SMEXPEFF'])
ax.set_title('g')
ax.set_xlabel('Mapped Unique Rate of Total')
ax.set_ylabel('Expression Profiling Efficiency:\n Ratio of exon reads to total reads')
# Out:
# Text(0, 0.5, 'Expression Profiling Efficiency:\n Ratio of exon reads to total reads')

# %%
fig, ax = plt.subplots()
ax.scatter(new_df['SMMPPDUN'], new_df['SME2SNSE'])
ax.set_title('g')
ax.set_xlabel('Number of reads that were aligned\n and did not have duplicate flags')
ax.set_ylabel('Number of End 2 reads that were\n sequenced in the sense direction')
# Out:
# Text(0, 0.5, 'Number of End 2 reads that were\n sequenced in the sense direction')

# %%
fig, ax = plt.subplots()
ax.scatter(new_df['SMMPPDUN'], new_df['SME2ANTI'])
ax.set_title('g')
ax.set_xlabel('Number of reads that were aligned\n and did not have duplicate flags')
ax.set_ylabel('End 2 Antisense:\nNumber of reads that were sequenced\n in the antisense direction')
# Out:
# Text(0, 0.5, 'End 2 Antisense:\nNumber of reads that were sequenced\n in the antisense direction')

# %%
fig, ax = plt.subplots()
ax.scatter(new_df['SME2ANTI'], new_df['SME2SNSE'])
ax.set_title('g')
ax.set_xlabel('End 2 Antisense:\nNumber of reads that were sequenced\n in the antisense direction')
ax.set_ylabel('Number of End 2 reads that were\n sequenced in the sense direction')
# Out:
# Text(0, 0.5, 'Number of End 2 reads that were\n sequenced in the sense direction')

# %%
new_df.columns
# Out:
# Index(['SUBJID', 'SAMPID', 'SMRIN', 'SMTS', 'SMTSD', 'SMUBRID', 'SMTSISCH',
#        'SMNABTCH', 'SMNABTCHT', 'SMNABTCHD', 'SMGEBTCH', 'SMGEBTCHD',
#        'SMGEBTCHT', 'SMAFRZE', 'SME2MPRT', 'SMCHMPRS', 'SMNTRART', 'SMMAPRT',
#        'SMEXNCRT', 'SMGNSDTC', 'SMUNMPRT', 'SMRDLGTH', 'SME1MMRT', 'SMSFLGTH',
#        'SMESTLBS', 'SMMPPD', 'SMNTERRT', 'SMRRNANM', 'SMRDTTL', 'SMVQCFL',
#        'SMTRSCPT', 'SMMPPDPR', 'SMUNPDRD', 'SMNTRNRT', 'SMMPUNRT', 'SMEXPEFF',
#        'SMMPPDUN', 'SME2MMRT', 'SME2ANTI', 'SMALTALG', 'SME2SNSE', 'SMMFLGTH',
#        'SME1ANTI', 'SMSPLTRD', 'SMBSMMRT', 'SME1SNSE', 'SME1PCTS', 'SMRRNART',
#        'SME1MPRT', 'SMDPMPRT', 'SME2PCTS'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['SUBJID', 'SAMPID', 'SMATSSCR', 'SMCENTER', 'SMPTHNTS', 'SMRIN', 'SMTS',
#        'SMTSD', 'SMUBRID', 'SMTSISCH', 'SMTSPAX', 'SMNABTCH', 'SMNABTCHT',
#        'SMNABTCHD', 'SMGEBTCH', 'SMGEBTCHD', 'SMGEBTCHT', 'SMAFRZE', 'SMGTC',
#        'SME2MPRT', 'SMCHMPRS', 'SMNTRART', 'SMNUMGPS', 'SMMAPRT', 'SMEXNCRT',
#        'SM550NRM', 'SMGNSDTC', 'SMUNMPRT', 'SM350NRM', 'SMRDLGTH', 'SMMNCPB',
#        'SME1MMRT', 'SMSFLGTH', 'SMESTLBS', 'SMMPPD', 'SMNTERRT', 'SMRRNANM',
#        'SMRDTTL', 'SMVQCFL', 'SMMNCV', 'SMTRSCPT', 'SMMPPDPR', 'SMCGLGTH',
#        'SMGAPPCT', 'SMUNPDRD', 'SMNTRNRT', 'SMMPUNRT', 'SMEXPEFF', 'SMMPPDUN',
#        'SME2MMRT', 'SME2ANTI', 'SMALTALG', 'SME2SNSE', 'SMMFLGTH', 'SME1ANTI',
#        'SMSPLTRD', 'SMBSMMRT', 'SME1SNSE', 'SME1PCTS', 'SMRRNART', 'SME1MPRT',
#        'SMNUM5CD', 'SMDPMPRT', 'SME2PCTS'],
#       dtype='object')

# %%
hypo_df1 = new_df[['SMRIN','SMTSISCH']]

# %%
# type(hypo_df1['SMTSISCH'][154])
hypo_df1['SMTSISCH'][154] == "NaN"
# Out:
# False

# %%
hypo_df1.dropna(how='any', inplace=True)
# Out:
# /home/farzady/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
hypo_df1[hypo_df1['SMTSISCH']<0]['SMTSISCH'].min()
# Out:
# -1226.0

# %%
hypo_df_high = hypo_df1[hypo_df1['SMRIN'] >=5.7]
hypo_df_low = hypo_df1[hypo_df1['SMRIN'] < 5.7]

# %%
hypo_df_low.shape
# Out:
# (27, 2)

# %%
low_RIN_samples = np.array(hypo_df_low['SMTSISCH'])
high_RIN_samples = np.array(hypo_df_high['SMTSISCH'])

# %%
fig, ax = plt.subplots(1, figsize=(16, 3))

ax.scatter(low_RIN_samples, np.repeat(0, len(low_RIN_samples)) + np.random.normal(0, 0.1, len(low_RIN_samples)), s=5)
ax.scatter(high_RIN_samples, np.repeat(1, len(high_RIN_samples)) + np.random.normal(0, 0.1, len(high_RIN_samples)), s=5)
ax.set_yticks([0, 1])
ax.set_yticklabels(["low_RIN_samples", "high_RIN_samples"])
# Out:
# [Text(0, 0, 'low_RIN_samples'), Text(0, 0, 'high_RIN_samples')]

# %%
len(high_RIN_samples)
len(low_RIN_samples)
# Out:
# 27

# %%
def welch_test_statistic(low_RIN_samples, high_RIN_samples):
    numerator = np.mean(low_RIN_samples) - np.mean(high_RIN_samples)
    denominator_sq = (np.var(low_RIN_samples) / len(low_RIN_samples)) + (np.var(high_RIN_samples) / len(high_RIN_samples))
    return numerator / np.sqrt(denominator_sq)

# %%
test_statistic = welch_test_statistic(low_RIN_samples, high_RIN_samples)
print("Welch Test Statistic: {:2.2f}".format(test_statistic))
# Out:
# Welch Test Statistic: 2.02

# %%
def welch_satterhwaithe_df(low_RIN_samples, high_RIN_samples):
    ss1 = len(low_RIN_samples)
    ss2 = len(high_RIN_samples)
    df = (
        ((np.var(low_RIN_samples)/ss1 + np.var(high_RIN_samples)/ss2)**(2.0)) / 
        ((np.var(low_RIN_samples)/ss1)**(2.0)/(ss1 - 1) + (np.var(high_RIN_samples)/ss2)**(2.0)/(ss2 - 1))
    )
    return df

# %%
df = welch_satterhwaithe_df(low_RIN_samples, high_RIN_samples)
print("Degrees of Freedom for Welch's Test: {:2.2f}".format(df))
# Out:
# Degrees of Freedom for Welch's Test: 26.16

# %%
x = np.linspace(-3, 3, num=250)

fig, ax = plt.subplots(1, figsize=(16, 3))
students = stats.t(df)
ax.plot(x, students.pdf(x), linewidth=2, label="Degree of Freedom: {:2.2f}".format(df))
ax.legend()
ax.set_title("Distribution of Welsh's Test Statistic Under the Null Hypothesis")
# Out:
# Text(0.5, 1.0, "Distribution of Welsh's Test Statistic Under the Null Hypothesis")

# %%
x = np.linspace(-3, 3, num=250)

fig, ax = plt.subplots(1, figsize=(16, 3))
students = stats.t(df)
ax.plot(x, students.pdf(x), linewidth=2, label="Degree of Freedom: {:2.2f}".format(df))
_ = ax.fill_between(x, students.pdf(x), where=(x <= -test_statistic), color="red", alpha=0.25)
_ = ax.fill_between(x, students.pdf(x), where=(x >= test_statistic), color="red", alpha=0.25)
ax.legend()
ax.set_title("p-value Region")
# Out:
# Text(0.5, 1.0, 'p-value Region')

# %%
test_statistic = welch_test_statistic(low_RIN_samples, high_RIN_samples)

p_value = 1 - students.cdf(test_statistic)
print("p-value for Nick average kickflip height greater than Matt: {:2.3f}".format(p_value))
# Out:
# p-value for Nick average kickflip height greater than Matt: 0.027

# %%
hypo_df2 = hypo_df1[hypo_df1['SMTSISCH'] >= 0]

# %%
hypo_df3 = hypo_df1[hypo_df1['SMTSISCH'] <= 0]
hypo_df3
# Out:
#       SMRIN  SMTSISCH
# 2141    8.3    -118.0
# 2142    9.4    -124.0
# 2143    8.1    -178.0
# 2144    8.2    -127.0
# 2145    8.8     -37.0
# ...     ...       ...
# 7079   10.0    -106.0
# 7084   10.0    -112.0
# 7086   10.0     -76.0
# 7087   10.0     -22.0
# 7088   10.0     -43.0
#
# [297 rows x 2 columns]

# %%
len(hypo_df3['SMTSISCH'])
# Out:
# 297

# %%
hypo_df_high = hypo_df2[hypo_df1['SMRIN'] >= 7.5]
hypo_df_low = hypo_df2[hypo_df1['SMRIN'] < 7.5]
# Out:
# /home/farzady/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /home/farzady/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
low_RIN_samples = np.array(hypo_df_low['SMTSISCH'])
high_RIN_samples = np.array(hypo_df_high['SMTSISCH'])

# %%
low_RIN_samples
low_RIN_samples.mean()
# Out:
# 611.1205882352941

# %%
high_RIN_samples
high_RIN_samples.mean()
# Out:
# 410.5908029878618

# %%
fig, ax = plt.subplots(1, figsize=(16, 4))

ax.scatter(low_RIN_samples, np.repeat(0, len(low_RIN_samples)) + np.random.normal(0, 0.1, len(low_RIN_samples)), s=4)
ax.scatter(high_RIN_samples, np.repeat(1, len(high_RIN_samples)) + np.random.normal(0, 0.1, len(high_RIN_samples)), s=4)
ax.set_yticks([0, 1])
ax.set_yticklabels(["low_RIN_samples", "high_RIN_samples"])
# Out:
# [Text(0, 0, 'low_RIN_samples'), Text(0, 0, 'high_RIN_samples')]

# %%
len(low_RIN_samples)
# len(high_RIN_samples)
# Out:
# 6120

# %%
def welch_test_statistic(low_RIN_samples, high_RIN_samples):
    numerator = np.mean(low_RIN_samples) - np.mean(high_RIN_samples)
    denominator_sq = (np.var(low_RIN_samples) / len(low_RIN_samples)) + (np.var(high_RIN_samples) / len(high_RIN_samples))
    return numerator / np.sqrt(denominator_sq)

# %%
test_statistic = welch_test_statistic(low_RIN_samples, high_RIN_samples)
print("Welch Test Statistic: {:2.2f}".format(test_statistic))
# Out:
# Welch Test Statistic: 27.82

# %%
def welch_satterhwaithe_df(low_RIN_samples, high_RIN_samples):
    ss1 = len(low_RIN_samples)
    ss2 = len(high_RIN_samples)
    df = (
        ((np.var(low_RIN_samples)/ss1 + np.var(high_RIN_samples)/ss2)**(2.0)) / 
        ((np.var(low_RIN_samples)/ss1)**(2.0)/(ss1 - 1) + (np.var(high_RIN_samples)/ss2)**(2.0)/(ss2 - 1))
    )
    return df

# %%
df = welch_satterhwaithe_df(low_RIN_samples, high_RIN_samples)
print("Degrees of Freedom for Welch's Test: {:2.2f}".format(df))
# Out:
# Degrees of Freedom for Welch's Test: 9728.21

# %%
x = np.linspace(-3, 3, num=250)

fig, ax = plt.subplots(1, figsize=(16, 3))
students = stats.t(df)
ax.plot(x, students.pdf(x), linewidth=2, label="Degree of Freedom: {:2.2f}".format(df))
ax.legend()
ax.set_title("Distribution of Welsh's Test Statistic Under the Null Hypothesis")
# Out:
# Text(0.5, 1.0, "Distribution of Welsh's Test Statistic Under the Null Hypothesis")

# %%
x = np.linspace(-3, 3, num=250)

fig, ax = plt.subplots(1, figsize=(16, 3))
students = stats.t(df)
ax.plot(x, students.pdf(x), linewidth=2, label="Degree of Freedom: {:2.2f}".format(df))
_ = ax.fill_between(x, students.pdf(x), where=(x >= test_statistic), color="red", alpha=0.25)
_ = ax.fill_between(x, students.pdf(x), where=(x <= -test_statistic), color="red", alpha=0.25)
ax.legend()
ax.set_title("p-value Region")
# Out:
# Text(0.5, 1.0, 'p-value Region')

# %%
test_statistic = welch_test_statistic(low_RIN_samples, high_RIN_samples)

p_value = 1 - students.cdf(test_statistic)
print("p-value for Nick average kickflip height greater than Matt: {:2.3f}".format(p_value))
# Out:
# p-value for Nick average kickflip height greater than Matt: 0.000

# %%
plt.hist(hypo_df2['SMRIN'], bins=25);

# %%
hypo_df2.columns
# Out:
# Index(['SMRIN', 'SMTSISCH'], dtype='object')

# %%
hypo_df2['SMTSISCH'].max() - hypo_df2['SMTSISCH'].min()
# Out:
# 1737.0

# %%
time_mean = hypo_df2['SMTSISCH'].mean()
time_mean
# Out:
# 528.5495001922337

# %%
hypo_df_high_time = hypo_df2[hypo_df1['SMTSISCH'] >= time_mean]
hypo_df_low_time = hypo_df2[hypo_df1['SMTSISCH'] < time_mean]
# Out:
# /home/farzady/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /home/farzady/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
low_time_samples = np.array(hypo_df_low_time['SMTSISCH'])
high_time_samples = np.array(hypo_df_high_time['SMTSISCH'])

# %%
len(low_time_samples)
len(high_time_samples)
# Out:
# 4494

# %%
def welch_test_statistic(low_time_samples, high_time_samples):
    numerator = np.mean(low_time_samples) - np.mean(high_time_samples)
    denominator_sq = (np.var(low_time_samples) / len(low_time_samples)) + (np.var(high_time_samples) / len(high_time_samples))
    return numerator / np.sqrt(denominator_sq)

# %%
test_statistic = welch_test_statistic(low_time_samples, high_time_samples)
print("Welch Test Statistic: {:2.2f}".format(test_statistic))
# Out:
# Welch Test Statistic: -155.49

# %%
def welch_satterhwaithe_df(low_time_samples, high_time_samples):
    ss1 = len(low_time_samples)
    ss2 = len(high_time_samples)
    df = (
        ((np.var(low_time_samples)/ss1 + np.var(high_time_samples)/ss2)**(2.0)) / 
        ((np.var(low_time_samples)/ss1)**(2.0)/(ss1 - 1) + (np.var(high_time_samples)/ss2)**(2.0)/(ss2 - 1))
    )
    return df

# %%
df = welch_satterhwaithe_df(low_time_samples, high_RIN_samples)
print("Degrees of Freedom for Welch's Test: {:2.2f}".format(df))
# Out:
# Degrees of Freedom for Welch's Test: 5076.99

# %%
x = np.linspace(-3, 3, num=250)

fig, ax = plt.subplots(1, figsize=(16, 3))
students = stats.t(df)
ax.plot(x, students.pdf(x), linewidth=2, label="Degree of Freedom: {:2.2f}".format(df))
ax.legend()
ax.set_title("Distribution of Welsh's Test Statistic Under the Null Hypothesis")
# Out:
# Text(0.5, 1.0, "Distribution of Welsh's Test Statistic Under the Null Hypothesis")

# %%
x = np.linspace(-3, 3, num=250)

fig, ax = plt.subplots(1, figsize=(16, 3))
students = stats.t(df)
ax.plot(x, students.pdf(x), linewidth=2, label="Degree of Freedom: {:2.2f}".format(df))
_ = ax.fill_between(x, students.pdf(x), where=(x >= test_statistic), color="red", alpha=0.25)
_ = ax.fill_between(x, students.pdf(x), where=(x <= -test_statistic), color="red", alpha=0.25)
ax.legend()
ax.set_title("p-value Region")
# Out:
# Text(0.5, 1.0, 'p-value Region')

# %%
test_statistic = welch_test_statistic(low_time_samples, high_time_samples)

p_value = 1 - students.cdf(test_statistic)
print("p-value: {:2.3f}".format(p_value))
# Out:
# p-value: 1.000

# %%
hypo_df4 = df[['SMATSSCR','SMRIN']]

# %%
hypo_df4.shape
# Out:
# (14900, 2)

# %%
hypo_df4.dropna(how='any', inplace=True)
# Out:
# /home/farzady/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
hypo_df4.shape
# Out:
# (10391, 2)

# %%
hypo_df4.boxplot(column = 'SMRIN', by = 'SMATSSCR', figsize = (10,4))

# %%
hypo_df4_low = hypo_df4[hypo_df4['SMRIN'] < 7.5]
hypo_df4_high = hypo_df4[hypo_df4['SMRIN'] >= 7.5]

# %%
samples_A = np.array(hypo_df4_low['SMATSSCR'])
samples_B = np.array(hypo_df4_high['SMATSSCR'])

# %%
samples_A.mean()
# Out:
# 0.9734250429889011

# %%
samples_B.mean()
# Out:
# 0.7373560340510766

# %%
def welch_test_statistic(samples_A, samples_B):
    numerator = np.mean(samples_A) - np.mean(samples_B)
    denominator_sq = (np.var(samples_A) / len(samples_A)) + (np.var(samples_B) / len(samples_B))
    return numerator / np.sqrt(denominator_sq)

# %%
test_statistic = welch_test_statistic(samples_A, samples_B)
print("Welch Test Statistic: {:2.2f}".format(test_statistic))
# Out:
# Welch Test Statistic: 20.76

# %%
def welch_satterhwaithe_df(samples_A, samples_B):
    ss1 = len(samples_A)
    ss2 = len(samples_B)
    df = (
        ((np.var(samples_A)/ss1 + np.var(samples_B)/ss2)**(2.0)) / 
        ((np.var(samples_B)/ss1)**(2.0)/(ss1 - 1) + (np.var(samples_B)/ss2)**(2.0)/(ss2 - 1))
    )
    return df

# %%
df = welch_satterhwaithe_df(samples_A, samples_B)
print("Degrees of Freedom for Welch's Test: {:2.2f}".format(df))
# Out:
# Degrees of Freedom for Welch's Test: 11722.40

# %%
x = np.linspace(-3, 3, num=250)

fig, ax = plt.subplots(1, figsize=(16, 3))
students = stats.t(df)
ax.plot(x, students.pdf(x), linewidth=2, label="Degree of Freedom: {:2.2f}".format(df))
ax.legend()
ax.set_title("Distribution of Welsh's Test Statistic Under the Null Hypothesis")
# Out:
# Text(0.5, 1.0, "Distribution of Welsh's Test Statistic Under the Null Hypothesis")

# %%
x = np.linspace(-3, 3, num=250)

fig, ax = plt.subplots(1, figsize=(16, 3))
students = stats.t(df)
ax.plot(x, students.pdf(x), linewidth=2, label="Degree of Freedom: {:2.2f}".format(df))
_ = ax.fill_between(x, students.pdf(x), where=(x >= test_statistic), color="red", alpha=0.25)
_ = ax.fill_between(x, students.pdf(x), where=(x <= -test_statistic), color="red", alpha=0.25)
ax.legend()
ax.set_title("p-value Region")
# Out:
# Text(0.5, 1.0, 'p-value Region')

# %%
test_statistic = welch_test_statistic(samples_A, samples_B)

p_value = 1 - students.cdf(test_statistic)
print("p-value: {:2.3f}".format(p_value))
# Out:
# p-value: 0.000

# %%
x = np.linspace(-3, 3, num=250)

fig, ax = plt.subplots(1, figsize=(16, 3))

for i in [1,2,4,100]:
    students = stats.t(i)
    ax.plot(x, students.pdf(x), linewidth=2)
